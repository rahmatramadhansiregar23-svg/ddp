# %% [markdown]
# <a href="https://colab.research.google.com/github/rahmatramadhansiregar23-svg/ddp/blob/main/praktikum5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
namakendaraan = "beat ember"
jeniskendaraan = "motor"
cckendaraan = 200
warnakendaraan = "hitam"
rodakendaraan = 2

data_kendaraan = [namakendaraan, jeniskendaraan,
 cckendaraan, warnakendaraan, rodakendaraan]
print(data_kendaraan)

hargakendaraan = 5000
tipekendaraan = "metic"

data_kendaraan.append([hargakendaraan, tipekendaraan])
print(data_kendaraan)

merkkendaraan = "honda"
data_kendaraan.insert(2, merkkendaraan)
print(data_kendaraan)
# Out:
# ['beat ember', 'motor', 200, 'hitam', 2]
# ['beat ember', 'motor', 200, 'hitam', 2, [5000, 'metic']]
# ['beat ember', 'motor', 'honda', 200, 'hitam', 2, [5000, 'metic']]

# %%
pilihan = int(input("""
silahkan pilih menu yang diinginkan
===================================
1. luas persegi
2. luas lingkaran
3. luas segitiga
===================================
kirimkan hanya angka saja,
jawaban = """))

match pilihan:
 case 1:
  sisi = int(input("sisi = "))
  luas = sisi * sisi
  print(f"luas persegi dengan sisi {luas} adalah {luas}")
  # luas persegi
 case 2:
  luas_lingkaran
  phi * jari-jari * jari-jari
  print(f"luas lingkaran adalah {luas_lingkaran}")

 case 3:
  luas_segitiga
  (alas * tinggi)/2
  print(f"luas segitiga adalah {luas_segitiga}")

 case _:
  print("nda tau")
# Out:
# silahkan pilih menu yang diinginkan
# ...
# 1. luas persegi
# 2. luas lingkaran
# 3. luas segitiga
# ...
# kirimkan hanya angka saja,
# jawaban = 34
# nda tau
